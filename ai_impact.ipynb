# %%
# ============================================
# 🔎 EDA Inicial - Global AI Content Impact Dataset
# Paleta violeta-azulada
# ============================================

# 1. Importar librerías necesarias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Configuración de visualización (violetas y azules)
plt.style.use("seaborn-v0_8-darkgrid")
sns.set_palette("mako")  # tonos violeta-azulados
pd.set_option("display.max_columns", None)

# 2. Cargar el dataset
file_path = "Global_AI_Content_Impact_Dataset.csv"  # Ajusta la ruta si es necesario
df = pd.read_csv(file_path)

# 3. Información básica
print("📊 Dimensiones del dataset:", df.shape)
print("\n🧾 Tipos de datos:\n", df.dtypes)
print("\n🔍 Valores nulos por columna:\n", df.isnull().sum())

# 4. Vista previa de datos
display(df.head())

# 5. Resumen estadístico
print("\n📈 Resumen estadístico:")
display(df.describe())

# 6. Variables categóricas - distribución de frecuencias
categorical_cols = df.select_dtypes(include=["object"]).columns
for col in categorical_cols:
    print(f"\n📊 Distribución de {col}:")
    print(df[col].value_counts())
    plt.figure(figsize=(8,4))
    sns.countplot(data=df, x=col, order=df[col].value_counts().index, palette="crest")
    plt.xticks(rotation=45, ha="right")
    plt.title(f"Distribución de {col}", fontsize=12, color="navy")
    plt.show()

# 7. Histogramas de variables numéricas
numeric_cols = df.select_dtypes(include=[np.number]).columns
df[numeric_cols].hist(figsize=(15,12), bins=15, color="#5D3FD3", edgecolor='black')
plt.suptitle("Distribución de variables numéricas", fontsize=16, color="darkblue")
plt.show()

# 8. Boxplots para detección de outliers
plt.figure(figsize=(15,8))
sns.boxplot(data=df[numeric_cols], palette="mako")
plt.xticks(rotation=45)
plt.title("Distribución y outliers en variables numéricas", fontsize=14, color="midnightblue")
plt.show()

# 9. Mapa de correlaciones
plt.figure(figsize=(12,8))
corr = df[numeric_cols].corr()
sns.heatmap(corr, annot=True, cmap="PuBuGn", fmt=".2f", linewidths=0.5, cbar_kws={'shrink': 0.8})
plt.title("Mapa de correlaciones entre variables numéricas", fontsize=14, color="darkblue")
plt.show()

# ============================================
# ✅ Fin del EDA inicial
# ============================================
# Out:
# 📊 Dimensiones del dataset: (200, 12)
#
# 🧾 Tipos de datos:
#  Country                                        object
# Year                                            int64
# Industry                                       object
# AI Adoption Rate (%)                          float64
# AI-Generated Content Volume (TBs per year)    float64
# Job Loss Due to AI (%)                        float64
# Revenue Increase Due to AI (%)                float64
# Human-AI Collaboration Rate (%)               float64
# Top AI Tools Used                              object
# Regulation Status                              object
# Consumer Trust in AI (%)                      float64
# Market Share of AI Companies (%)              float64
# dtype: object
#
# 🔍 Valores nulos por columna:
#  Country                                       0
# Year                                          0
# Industry                                      0
# AI Adoption Rate (%)                          0
# AI-Generated Content Volume (TBs per year)    0
# Job Loss Due to AI (%)                        0
# Revenue Increase Due to AI (%)                0
# Human-AI Collaboration Rate (%)               0
# Top AI Tools Used                             0
# Regulation Status                             0
# Consumer Trust in AI (%)                      0
# Market Share of AI Companies (%)              0
# dtype: int64
#        Country  Year    Industry  AI Adoption Rate (%)  \
# 0  South Korea  2022       Media                 44.29
# 1        China  2025       Legal                 34.75
# 2          USA  2022  Automotive                 81.06
# 3       France  2021       Legal                 85.24
# 4       France  2021      Gaming                 78.95
#
#    AI-Generated Content Volume (TBs per year)  Job Loss Due to AI (%)  \
# 0                                       33.09                   16.77
# 1                                       66.74                   46.89
# 2                                       96.13                   10.66
# 3                                       93.76                   27.70
# 4                                       45.62                   17.45
#
#    Revenue Increase Due to AI (%)  Human-AI Collaboration Rate (%)  \
# 0                           46.12                            74.79
# 1                           52.46                            26.17
# 2                           45.60                            39.66
# 3                           78.24                            29.45
# 4                            1.05                            21.70
#
#   Top AI Tools Used Regulation Status  Consumer Trust in AI (%)  \
# 0              Bard            Strict                     40.77
# 1            DALL-E            Strict                     35.67
# 2  Stable Diffusion          Moderate                     54.47
# 3            Claude          Moderate                     51.84
# 4        Midjourney            Strict                     41.77
#
#    Market Share of AI Companies (%)
# 0                             18.73
# 1                             35.02
# 2                             22.76
# 3                              1.93
# 4                             21.41
# 📈 Resumen estadístico:
#               Year  AI Adoption Rate (%)  \
# count   200.000000            200.000000
# mean   2022.315000             54.265850
# std       1.825496             24.218067
# min    2020.000000             10.530000
# 25%    2021.000000             33.222500
# 50%    2022.000000             53.310000
# 75%    2024.000000             76.220000
# max    2025.000000             94.760000
#
#        AI-Generated Content Volume (TBs per year)  Job Loss Due to AI (%)  \
# count                                   200.00000              200.000000
# mean                                     46.07260               25.788250
# std                                      29.16122               13.901105
# min                                       1.04000                0.090000
# 25%                                      20.32250               14.995000
# 50%                                      44.32000               25.735000
# 75%                                      71.62000               37.417500
# max                                      99.06000               49.710000
#
#        Revenue Increase Due to AI (%)  Human-AI Collaboration Rate (%)  \
# count                      200.000000                       200.000000
# mean                        39.719450                        54.102150
# std                         23.829545                        19.247079
# min                          0.140000                        20.210000
# 25%                         17.907500                        37.770000
# 50%                         42.100000                        54.515000
# 75%                         58.697500                        69.402500
# max                         79.550000                        88.290000
#
#        Consumer Trust in AI (%)  Market Share of AI Companies (%)
# count                200.000000                        200.000000
# mean                  59.425150                         26.569550
# std                   17.319668                         14.023729
# min                   30.120000                          1.180000
# 25%                   44.755000                         14.052500
# 50%                   59.215000                         27.390000
# 75%                   74.885000                         38.432500
# max                   89.880000                         49.280000
# 📊 Distribución de Country:
# Country
# India          24
# France         24
# Japan          22
# China          21
# USA            21
# South Korea    20
# UK             20
# Germany        17
# Canada         16
# Australia      15
# Name: count, dtype: int64
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_7512\4294917321.py:39: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, order=df[col].value_counts().index, palette="crest")
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_7512\4294917321.py:39: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, order=df[col].value_counts().index, palette="crest")
# 📊 Distribución de Industry:
# Industry
# Media            31
# Gaming           27
# Retail           21
# Automotive       19
# Marketing        19
# Manufacturing    18
# Legal            17
# Education        17
# Healthcare       17
# Finance          14
# Name: count, dtype: int64
# 📊 Distribución de Top AI Tools Used:
# Top AI Tools Used
# Midjourney          37
# Claude              31
# ChatGPT             31
# Stable Diffusion    27
# DALL-E              26
# Bard                24
# Synthesia           24
# Name: count, dtype: int64
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_7512\4294917321.py:39: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, order=df[col].value_counts().index, palette="crest")
# 📊 Distribución de Regulation Status:
# Regulation Status
# Moderate    76
# Lenient     63
# Strict      61
# Name: count, dtype: int64
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_7512\4294917321.py:39: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, order=df[col].value_counts().index, palette="crest")

# %%
# ============================================
# 🔄 ETL - Global AI Content Impact Dataset
# ============================================

# 1. Importar librerías
import pandas as pd

# 2. EXTRACTION - Cargar datos
file_path = "Global_AI_Content_Impact_Dataset.csv"  # Ajusta la ruta si es necesario
df_raw = pd.read_csv(file_path)

print("✅ Datos extraídos")
print("Dimensiones iniciales:", df_raw.shape)

# 3. TRANSFORMATION - Limpieza y preparación
df = df_raw.copy()

# --- A) Normalización de nombres de columnas ---
df.columns = (df.columns
              .str.strip()
              .str.replace(" ", "_")
              .str.replace("-", "_")
              .str.replace(r"[%()]", "", regex=True)
              .str.lower()
              .str.replace("__", "_"))  # corregir dobles guiones bajos

print("\n📑 Nuevos nombres de columnas:")
print(df.columns.tolist())

# --- B) Eliminar duplicados ---
duplicates = df.duplicated().sum()
if duplicates > 0:
    df = df.drop_duplicates()
    print(f"\n⚠️ {duplicates} duplicados eliminados")
else:
    print("\n✅ No se encontraron duplicados")

# --- C) Revisar valores nulos ---
print("\n🔍 Valores nulos por columna:")
print(df.isnull().sum())

# --- D) Conversión de tipos ---
df["year"] = df["year"].astype(int)
numeric_cols = df.select_dtypes(include="number").columns
df[numeric_cols] = df[numeric_cols].apply(pd.to_numeric, errors="coerce")

# --- E) Normalizar categorías ---
if "regulation_status" in df.columns:
    df["regulation_status"] = df["regulation_status"].str.strip().str.capitalize()

# --- F) Asegurar nombres clave para métricas ---
rename_map = {
    "ai_adoption_rate_": "ai_adoption_rate",
    "ai_adoption_rate__": "ai_adoption_rate",
    "human_ai_collaboration_rate": "human_ai_collaboration_rate",
    "job_loss_due_to_ai": "job_loss_due_to_ai",
    "revenue_increase_due_to_ai": "revenue_increase_due_to_ai"
}
df = df.rename(columns={k: v for k, v in rename_map.items() if k in df.columns})

print("\n📑 Columnas finales después de renombrado:")
print(df.columns.tolist())

# --- G) Crear columna derivada ---
if {"ai_adoption_rate", "revenue_increase_due_to_ai", "human_ai_collaboration_rate", "job_loss_due_to_ai"}.issubset(df.columns):
    df["ai_impact_index"] = (
        df["ai_adoption_rate"]*0.4 +
        df["revenue_increase_due_to_ai"]*0.3 +
        df["human_ai_collaboration_rate"]*0.2 -
        df["job_loss_due_to_ai"]*0.1
    )
    print("\n🆕 Columna derivada 'ai_impact_index' creada con éxito")
else:
    print("\n⚠️ No se encontraron todas las columnas necesarias para calcular 'ai_impact_index'")

# 4. LOAD - Guardar dataset limpio
output_file = "Global_AI_Content_Clean.csv"
df.to_csv(output_file, index=False)

print(f"\n💾 Dataset limpio guardado como: {output_file}")
print("Dimensiones finales:", df.shape)

# Vista previa final
display(df.head())
# Out:
# ✅ Datos extraídos
# Dimensiones iniciales: (200, 12)
#
# 📑 Nuevos nombres de columnas:
# ['country', 'year', 'industry', 'ai_adoption_rate_', 'ai_generated_content_volume_tbs_per_year', 'job_loss_due_to_ai_', 'revenue_increase_due_to_ai_', 'human_ai_collaboration_rate_', 'top_ai_tools_used', 'regulation_status', 'consumer_trust_in_ai_', 'market_share_of_ai_companies_']
#
# ✅ No se encontraron duplicados
#
# 🔍 Valores nulos por columna:
# country                                     0
# year                                        0
# industry                                    0
# ai_adoption_rate_                           0
# ai_generated_content_volume_tbs_per_year    0
# job_loss_due_to_ai_                         0
# revenue_increase_due_to_ai_                 0
# human_ai_collaboration_rate_                0
# top_ai_tools_used                           0
# regulation_status                           0
# consumer_trust_in_ai_                       0
# market_share_of_ai_companies_               0
# dtype: int64
#
# 📑 Columnas finales después de renombrado:
# ['country', 'year', 'industry', 'ai_adoption_rate', 'ai_generated_content_volume_tbs_per_year', 'job_loss_due_to_ai_', 'revenue_increase_due_to_ai_', 'human_ai_collaboration_rate_', 'top_ai_tools_used', 'regulation_status', 'consumer_trust_in_ai_', 'market_share_of_ai_companies_']
#
# ⚠️ No se encontraron todas las columnas necesarias para calcular 'ai_impact_index'
#
# 💾 Dataset limpio guardado como: Global_AI_Content_Clean.csv
# Dimensiones finales: (200, 12)
#        country  year    industry  ai_adoption_rate  \
# 0  South Korea  2022       Media             44.29
# 1        China  2025       Legal             34.75
# 2          USA  2022  Automotive             81.06
# 3       France  2021       Legal             85.24
# 4       France  2021      Gaming             78.95
#
#    ai_generated_content_volume_tbs_per_year  job_loss_due_to_ai_  \
# 0                                     33.09                16.77
# 1                                     66.74                46.89
# 2                                     96.13                10.66
# 3                                     93.76                27.70
# 4                                     45.62                17.45
#
#    revenue_increase_due_to_ai_  human_ai_collaboration_rate_  \
# 0                        46.12                         74.79
# 1                        52.46                         26.17
# 2                        45.60                         39.66
# 3                        78.24                         29.45
# 4                         1.05                         21.70
#
#   top_ai_tools_used regulation_status  consumer_trust_in_ai_  \
# 0              Bard            Strict                  40.77
# 1            DALL-E            Strict                  35.67
# 2  Stable Diffusion          Moderate                  54.47
# 3            Claude          Moderate                  51.84
# 4        Midjourney            Strict                  41.77
#
#    market_share_of_ai_companies_
# 0                          18.73
# 1                          35.02
# 2                          22.76
# 3                           1.93
# 4                          21.41
